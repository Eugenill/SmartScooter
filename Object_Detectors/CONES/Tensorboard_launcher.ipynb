# %% [markdown]
# ###Mount drive (Every Time)

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# %cd /content/drive/My Drive/SMART_SCOOTER
#!git clone https://github.com/mixuala/colab_utils
# !wget https://bin.equinox.io/c/4VmDzA7iaHb/ngrok-stable-linux-amd64.zip
# !unzip ngrok-stable-linux-amd64.zip
# Out:
# /content/drive/My Drive/SMART_SCOOTER
# --2020-04-05 19:23:42--  https://bin.equinox.io/c/4VmDzA7iaHb/ngrok-stable-linux-amd64.zip
# Resolving bin.equinox.io (bin.equinox.io)... 34.235.56.240, 3.228.72.85, 52.5.204.126, ...
# Connecting to bin.equinox.io (bin.equinox.io)|34.235.56.240|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 13773305 (13M) [application/octet-stream]
# Saving to: ‘ngrok-stable-linux-amd64.zip’
#
# ngrok-stable-linux- 100%[===================>]  13.13M  5.89MB/s    in 2.2s
#
# 2020-04-05 19:23:45 (5.89 MB/s) - ‘ngrok-stable-linux-amd64.zip’ saved [13773305/13773305]
#
# Archive:  ngrok-stable-linux-amd64.zip
# replace ngrok? [y]es, [n]o, [A]ll, [N]one, [r]ename: y
#   inflating: ngrok

# %%
# %cd /content/drive/My Drive/SMART_SCOOTER
import os
import colab_utils.tboard

# set paths
ROOT = %pwd
LOG_DIR = os.path.join(ROOT, 'training/TL/TL_v5')

# will install `ngrok`, if necessary
# will create `log_dir` if path does not exist
colab_utils.tboard.launch_tensorboard( bin_dir=ROOT, log_dir=LOG_DIR )
# Out:
# /content/drive/My Drive/SMART_SCOOTER
# ngrok installed
# status: tensorboard=False, ngrok=False
# ---------------------------------------------------------------------------
# ConnectionRefusedError                    Traceback (most recent call last)
# /usr/local/lib/python3.6/dist-packages/urllib3/connection.py in _new_conn(self)
#     158             conn = connection.create_connection(
# --> 159                 (self._dns_host, self.port), self.timeout, **extra_kw)
#     160
#
# /usr/local/lib/python3.6/dist-packages/urllib3/util/connection.py in create_connection(address, timeout, source_address, socket_options)
#      79     if err is not None:
# ---> 80         raise err
#      81
#
# /usr/local/lib/python3.6/dist-packages/urllib3/util/connection.py in create_connection(address, timeout, source_address, socket_options)
#      69                 sock.bind(source_address)
# ---> 70             sock.connect(sa)
#      71             return sock
#
# ...

# %%
# %cd /content/drive/My Drive/SMART_SCOOTER
# %load_ext tensorboard
LOG_DIR = '/content/drive/My Drive/SMART_SCOOTER/training/TL/TL_v5'
get_ipython().system_raw(
    'tensorboard --logdir {} --host 0.0.0.0 --port 6006 &'
    .format(LOG_DIR)
)
# Out:
# /content/drive/My Drive/SMART_SCOOTER
# The tensorboard extension is already loaded. To reload it, use:
#   %reload_ext tensorboard

# %%
get_ipython().system_raw('./ngrok http 6006 &')

# %%
! curl -s http://localhost:4040/api/tunnels | python3 -c \
    "import sys, json; obj=json.load(sys.stdin);print(obj['tunnels'][0]['public_url'])"
# Out:
# http://c6ea9870.ngrok.io

# %%
# %load_ext tensorboard
# !tensorboard --logdir '/content/drive/My Drive/SMART_SCOOTER/training/TL/TL_v5' --host localhost --port 6006
# Out:
# The tensorboard extension is already loaded. To reload it, use:
#   %reload_ext tensorboard
# W0405 19:24:20.740427 139727084812032 plugin_event_accumulator.py:323] Found more than one graph event per run, or there was a metagraph containing a graph_def, as well as one or more graph events.  Overwriting the graph with the newest event.
# W0405 19:24:20.768020 139727084812032 plugin_event_accumulator.py:335] Found more than one metagraph event per run. Overwriting the metagraph with the newest event.
# TensorBoard 2.2.0 at http://localhost:6006/ (Press CTRL+C to quit)
# W0405 19:24:22.822532 139727084812032 plugin_event_accumulator.py:323] Found more than one graph event per run, or there was a metagraph containing a graph_def, as well as one or more graph events.  Overwriting the graph with the newest event.
# W0405 19:24:22.832352 139727084812032 plugin_event_accumulator.py:335] Found more than one metagraph event per run. Overwriting the metagraph with the newest event.
# ...
